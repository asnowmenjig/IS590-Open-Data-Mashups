# %%
# general process outline

# take dataset files
# read top x number of rows into pandas dataframe (according to percentage_breakdowns_v2.xlsx)
# save new dataframe with only first_name, last_name, fraction_total
# rename fraction_total column -> [dataset]_total
# add empty columns for other dataset totals

#combine dataset files
## if first_name and last_name match, find average of fraction_total

# %%
import pandas
import numpy

# %%
# CHUNK: LOADING DATA

# %%
# EEBO

eebo_df = pandas.read_csv('../eebo/eebo_dataset_final.csv', nrows=40)
# eebo_df

# %%
eebo_df2 = eebo_df.loc[:, ['first_name', 'last_name', 'title', 'fraction_total']]
# eebo_df2

# %%
# ESTC

estc_df = pandas.read_csv('../estc/estc_dataset_final.csv', nrows=159)
# estc_df

# %%
estc_df2 = estc_df.loc[:, ['first_name', 'last_name', 'title', 'fraction_total']]
# estc_df2

# %%
# OPEN SYLLABUS

open_syllabus_df = pandas.read_csv('../open-syllabus/english-lit/open-syllabus_dataset_final.csv', nrows=250)
# open_syllabus_df

# %%
open_syllabus_df2 = open_syllabus_df.loc[:, ['first_name', 'last_name', 'title', 'fraction_total']]
# open_syllabus_df2

# %%
# OTA

ota_df = pandas.read_csv('../ota/ota_dataset_final.csv', nrows=31)
# ota_df

# %%
ota_df2 = ota_df.loc[:, ['first_name', 'last_name', 'title', 'fraction_total']]
# ota_df2

# %%
# PROJECT GUTENBERG

project_gutenberg_df = pandas.read_csv('../project-gutenberg-2/project-gutenberg_dataset_final.csv', nrows=1057)
# project_gutenberg_df

# %%
project_gutenberg_df2 = project_gutenberg_df.loc[:, ['first_name', 'last_name', 'title', 'fraction_total']]
# project_gutenberg_df2

# %%
# CHUNK: PROCESSING LOADED DATA

# %%
merged_df = pandas.concat((eebo_df2, estc_df2, open_syllabus_df2, ota_df2, project_gutenberg_df2))
merged_df
#  merged_df.groupby(merged_df.index).mean()
# Out:
# C:\Users\Jasmine\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                                first_name  fraction_total          last_name  \
# 0                               Anonymous        0.291590                NaN
# 1                              Parliament        0.011711  England and Wales
# 2                               Charles I        0.010643          Sovereign
# 3                       England and Wales        0.009838                NaN
# 4                       Church of England        0.009440                NaN
# 5                              Charles II        0.007148          Sovereign
# 6                           Privy Council        0.005735           Scotland
# 7                                 James I        0.004919          Sovereign
# 8                             Elizabeth I        0.004490          Sovereign
# 9                                  Thomas        0.004218          Sternhold
# 10            Parliament House of Commons        0.002951  England and Wales
# 11                                Richard        0.002826             Baxter
# 12                                 George        0.002627                Fox
# 13                                Gilbert        0.002240             Burnet
# 14                                   John        0.001999             Dryden
# 15                                   John        0.001968             Taylor
# 16                                 Joseph        0.001957               Hall
# 17                                William        0.001947               Penn
# 18                                William        0.001947            Perkins
# 19                       William and Mary        0.001894          Sovereign
# 20                                William        0.001727             Prynne
# 21                               James II        0.001695          Sovereign
# 22                                  Roger        0.001685         L'Estrange
# 23                                  Henry        0.001591              Smith
# 24                                  Simon        0.001580            Patrick
# 25                                Richard        0.001486          Allestree
# 26                                 Jeremy        0.001476             Taylor
# 27                                Francis        0.001287              Bacon
# 28                                Gervase        0.001277            Markham
# 29                                England        0.001245                NaN
# ...                                   ...             ...                ...
# 1027                               Robert        0.000149              Grant
# 1028                               Robert        0.000149             Walser
# 1029                            Robert J.        0.000149           Nemiroff
# 1030                         Robert Moore        0.000149           Williams
# 1031           Robert W. (Robert William)        0.000149            Service
# 1032                                  Rog        0.000149           Phillips
# 1033            Rollin H. (Rollin Harold)        0.000149              Baker
# 1034                       Rupert Sargent        0.000149            Holland
# 1035                                Selma        0.000149            Anttila
# 1036                       Stephen Lucius        0.000149              Gwynn
# 1037                               Temple        0.000149             Bailey
# 1038                               Thomas        0.000149             Malory
# 1039                               Thomas        0.000149             Hughes
# 1040                               Thomas        0.000149               Mann
# 1041                               Thomas        0.000149             Hoover
# 1042  W. E. B. (William Edward Burghardt)        0.000149            Du Bois
# 1043             W. S. (William Schwenck)        0.000149            Gilbert
# 1044                             Waldemar        0.000149            Bonsels
# 1045                              William        0.000149             Godwin
# 1046                         William Hale        0.000149              White
# 1047                        William Henry        0.000149             Holmes
# 1048                         William Pitt        0.000149           Scargill
# 1049        William T. (William Tecumseh)        0.000149            Sherman
# 1050                              Woodrow        0.000149             Wilson
# 1051                                Xiang        0.000149                Liu
# 1052                                  Xun        0.000149                 Lu
# 1053                                  NaN        0.000149               Ovid
# 1054                                  NaN        0.000149          Jean Paul
# 1055                                  NaN        0.000149               Saki
# 1056                                  NaN        0.000149             Horace
#
#      title
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# ...    ...
# 1027   NaN
# 1028   NaN
# 1029   NaN
# 1030   NaN
# 1031   NaN
# 1032   NaN
# 1033   NaN
# 1034   NaN
# 1035   NaN
# 1036   NaN
# 1037   NaN
# 1038   NaN
# 1039   NaN
# 1040   NaN
# 1041   NaN
# 1042   NaN
# 1043   NaN
# 1044   NaN
# 1045   NaN
# 1046   NaN
# 1047   NaN
# 1048   NaN
# 1049   NaN
# 1050   NaN
# 1051   NaN
# 1052   NaN
# 1053   NaN
# 1054   NaN
# 1055   NaN
# 1056   NaN
#
# [1537 rows x 4 columns]
